# %% [markdown]
# # My First Notebook

# %%
# %matplotlib inline
# %run RollDieDynamic.py 200 1

# %%
from IPython.display import HTML
HTML(die_animation.to_jshtml())
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/matplotlib/animation.py:916: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/matplotlib/animation.py:916: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
# ...

# %%
# %matplotlib inline
# %run RollDieDynamic.py 200 1

# %%
from IPython.display import HTML
from RollDieDynamic import make_die_animation

# %%
anim = make_die_animation(200, 1)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x79f34c696340> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/matplotlib/pyplot.py:300, in _draw_all_if_interactive()
#     298 def _draw_all_if_interactive() -> None:
#     299     if matplotlib.is_interactive():
# --> 300         draw_all()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/_pylab_helpers.py:133, in Gcf.draw_all(cls, force)
#     131 for manager in cls.get_all_fig_managers():
#     132     if force or manager.canvas.figure.stale:
# --> 133         manager.canvas.draw_idle()
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/backend_bases.py:1989, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1987 if not self._is_idle_drawing:
#    1988     with self._idle_draw_cntx():
# ...

# %%
HTML(anim.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 HTML(anim.to_jshtml())
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/animation.py:1392, in Animation.to_jshtml(self, fps, embed_frames, default_mode)
#    1388         path = Path(tmpdir, "temp.html")
#    1389         writer = HTMLWriter(fps=fps,
#    1390                             embed_frames=embed_frames,
#    1391                             default_mode=default_mode)
# -> 1392         self.save(str(path), writer=writer)
#    1393         self._html_representation = path.read_text()
#    1395 return self._html_representation
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/animation.py:1125, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
# ...
